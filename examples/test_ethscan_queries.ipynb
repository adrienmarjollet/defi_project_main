# %%
# %load_ext autoreload
# %autoreload 2

import os
import json
import time
import cryo
from dotenv import load_dotenv
import pandas as pd
import polars as pl
from web3 import Web3

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

from io import StringIO

from blocks_scraping.dev.etherscan.etherscan_queries import EtherScanQueries


etherscan_queries = EtherScanQueries()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ETHERSCAN_API_TOKEN
# Env variable ETHERSCAN_API_TOKEN loaded.

# %%
adr_pepe_whale = '0x28c6c06298d514db089934071355e5743bf21d60'
wei_balance = etherscan_queries.get_erc20_balance(adr_pepe_whale)

# convert from wei to eth by hand
eth_balance = float(wei_balance['result']) / 10**18

eth_balance, eth_balance * 2704 # eth, dollars
# Out:
# (237641.41802489752, 642582394.3393229)

# %%
eth_price = etherscan_queries.get_eth_price()
# Out:
# {'status': '1', 'message': 'OK', 'result': '0'}

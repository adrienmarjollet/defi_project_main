# %%
import os

# show all env variables and print it line by line
for key in os.environ.keys():
    if 'PYTHON' in key:
        print(key + " : " + os.environ[key])
# Out:
# PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING : 1
# PYTHONIOENCODING : utf-8
# PYTHONPATH : C:\\Users\\adrie\Desktop\\Projects\\blockchain\\defi_project_main\\defi_library;C:\Users\adrie\Desktop\Projects\blockchain\defi_project_main\defi_library\
# PYTHONUNBUFFERED : 1
# PYTHON_FROZEN_MODULES : on

# %%
from common import misc
from pathlib import Path

assert misc.find_project_root_path() == Path(misc.find_project_root_path()), "find_project_root_path() should return Path object"
print("find_project_root_path() OK")
# Out:
# find_project_root_path() OK

# %%
# %load_ext autoreload
# %autoreload 2

from blocks_scraping.dev.web3.web3_queries import Web3Queries

from blocks_scraping.dev.cryo.rpc_queries import CryoTools

cryo_tool = CryoTools()

web3_tool = Web3Queries(provider_url=cryo_tool._rpc_url)

latest_block_number = web3_tool.get_latest_block()['number']

block_range = f"{latest_block_number-101}:{latest_block_number-1}/10"

address = '0x52c77b0CB827aFbAD022E6d6CAF2C44452eDbc39' # POOL SPX-WETH

contract_weth = '0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2' # WETH

contract_spx  = '0xE0f63A424a4439cBE457D80E4f4b51aD25b2c56C' # SPX

data_spx_pool  =  cryo_tool.fetch_erc20_balances(block_range, address, contract_spx, format='pandas', rps=200)

data_weth_pool =  cryo_tool.fetch_erc20_balances(block_range, address, contract_weth, format='pandas', rps=200)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Env variable ETH_RPC loaded.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 22
#      18 contract_weth = '0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2' # WETH
#      20 contract_spx  = '0xE0f63A424a4439cBE457D80E4f4b51aD25b2c56C' # SPX
# ---> 22 data_spx_pool  =  cryo_tool.fetch_erc20_balances(block_range, address, contract_spx, format='pandas', rps=200)
#      24 data_weth_pool =  cryo_tool.fetch_erc20_balances(block_range, address, contract_weth, format='pandas', rps=200)
#
# File ~\Desktop\Projects\blockchain\defi_project_main\defi_library\blocks_scraping\dev\cryo\rpc_queries.py:45, in CryoTools.fetch_erc20_balances(self, block_range, l_addresses, l_contracts, format, rps)
#      43 for address in l_addresses:
#      44     if not self._web3.is_address(address):
# ...

# %%
data_weth_pool
# Out:
#     chain_id  block_number                                       erc20  \
# 0          1      21797660  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1          1      21797661  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2          1      21797662  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3          1      21797663  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4          1      21797664  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..       ...           ...                                         ...
# 95         1      21797755  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 96         1      21797756  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 97         1      21797757  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 98         1      21797758  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 99         1      21797759  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
#                                        address      balance
# ...
